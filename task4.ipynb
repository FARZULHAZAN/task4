# %% [markdown]
# # import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as pl
import statistics as np
import seaborn as c
import numpy as n

# %%
d=pd.read_csv("C:\\Users\\91701\\Desktop\\Task4-20221230T062704Z-001\\Task4\\college_1.csv")

# %%
d
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
f=pd.read_csv("C:\\Users\\91701\\Desktop\\Task4-20221230T062704Z-001\\Task4\\college_2.csv")

# %%
f
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %% [markdown]
# # merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
h=pd.concat([d,f],ignore_index=True)

# %%
h
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# # Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)
# consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv
# if 10000<codekata score<15000 (Reached_expectations.csv)
# if 7000<codekata score<10000 (Needs_Improvement.csv)
# if codekate score < 7000 (Unsatisfactory.csv)

# %%
g=d[d["CodeKata Score"]>15000]

# %%
p=h[h["CodeKata Score"]>15000]

# %%
j=h[h["CodeKata Score"]<15000]

# %%
u=j[j["CodeKata Score"]>10000]

# %%
n=h[h["CodeKata Score"]<10000]

# %%
ne=n[n["CodeKata Score"]>7000]

# %%
un=h[h["CodeKata Score"]<7000]

# %%
u.to_csv("C:\\Users\\91701\\Desktop\\Reached_expectations.csv",mode="a",index=False,header=False)

# %%
p.to_csv("C:\\Users\\91701\\Desktop\\Exceeded expectations.csv",mode="a",index=False,header=False)

# %%
ne.to_csv("C:\\Users\\91701\\Desktop\\Needs_Improvement.csv",mode="a",index=False ,header=False)

# %%
un.to_csv("C:\\Users\\91701\\Desktop\\Unsatisfactory.csv",mode="a",index=False , header=False)

# %% [markdown]
# # Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
pl.plot(h["Previous Geekions"],h["CodeKata Score"])

# %% [markdown]
# # No of students participated¶

# %%
h["Name"].count()
# Out:
# 119

# %% [markdown]
# # Average completion of python course or my_sql or python english or computational thinking

# %%
h.fillna(0)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %%
pythoncom=np.mean(h["python"])

# %%
mysqlcom=np.mean(h["mysql"])

# %%
pythonencom=np.mean(abs(h["python_en"]))

# %%
compthin=np.mean(abs(h["computational_thinking"]))

# %%
pythoncom
# Out:
# 54.35294117647059

# %%
mysqlcom
# Out:
# 23.5

# %%
pythonencom
# Out:
# nan

# %%
compthin
# Out:
# nan

# %% [markdown]
# # rising star of the week (top 3 candidate who performed well in that particular week)

# %%
h.sort_values(by=["CodeKata Score"],ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# # Shining stars of the week (top 3 candidates who has highest geekions)

# %%
h.sort_values(by=["Previous Geekions"],ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# # Department wise codekata performence (pie chart)

# %%
q=h[h["Department"]=="Computer Science and Engineering"]

# %%
w=h[h["Department"]=="Electronics and Communication Engineering"]

# %%
e=h[h["Department"]=="Electronics and Electrical Engineering"]

# %%
ee=e["CodeKata Score"].sum()

# %%
elect=w["CodeKata Score"].sum()

# %%
comp=q["CodeKata Score"].sum()

# %%
x=[ee,elect,comp]

# %%
x
# Out:
# [53800, 108335, 320025]

# %%
y=["Electronics and Electrical Engineering","Electronics and Communication Engineering","Computer Science and Engineering"]

# %%
pl.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bec2e13520>,
# ...
#  [Text(1.0331051153206612, 0.3777483563144695, 'Electronics and Electrical Engineering'),
#   Text(0.17941479947329045, 1.0852697036819738, 'Electronics and Communication Engineering'),
#   Text(-0.5411938573983474, -0.9576581899165785, 'Computer Science and Engineering')])

# %% [markdown]
# # Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
c.set_style("whitegrid")
c.barplot(y=g["CodeKata Score"],x=g["Name"]).set(title="Computer Science")
cp1=list(g["CodeKata Score"])
b1=list(g["Name"])
print("TOPPER IN THIS SUBJECT "+ b1[cp1.index(max(cp1))])
# Out:
# TOPPER IN THIS SUBJECT A.Dharani

# %%
c.set_style("whitegrid")
c.barplot(y=w["CodeKata Score"],x=w["Name"]).set(title="Electronics and Communication Engineering")
cp=list(w["CodeKata Score"])
b=list(w["Name"])
print("TOPPER IN THIS SUBJECT "+ b[cp.index(max(cp))])
# Out:
# TOPPER IN THIS SUBJECT Bodipudi Harini

# %%
c.set_style("whitegrid")
c.barplot(y=e["CodeKata Score"],x=e["Name"]).set(title="Electronics and Electrical Engineering")
cp2=list(e["CodeKata Score"])
b2=list(e["Name"])
print("TOPPER IN THIS SUBJECT "+ b2[cp2.index(max(cp2))])
# Out:
# TOPPER IN THIS SUBJECT ASHOK KUMAR K
